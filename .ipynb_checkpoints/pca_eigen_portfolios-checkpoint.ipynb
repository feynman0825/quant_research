# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
import os
from sklearn.manifold import TSNE
import sklearn.decomposition
import seaborn as sns

from jqdatasdk import *
auth('17780620786','xxb19880825')
#auth('15397649986','dd111477')

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
def check_for_nulls(df):
    """
    Test and report number of NAs in each column of the input data frame
    :param df: pandas.DataFrame
    :return: None
    """
    null_dict = {}
    for col in df.columns.values:
        num_nans = np.sum(df[col].isnull())
        if num_nans > 0:
            print('%d Nans in col %s' % (num_nans, col))
        null_dict[col] = num_nans
    print('New shape of df: ', df.shape)
    return null_dict

# %%
start_date = '2006-01-01'
end_date = '2017-12-31'
price_df = pd.read_csv('price.csv',parse_dates=[0],dtype={'paused':np.bool})
price_df = price_df[price_df.date>start_date]
index_df = get_price(['000300.XSHG'],start_date=start_date, end_date=end_date)['close']

# %%
HF300_stocks = get_index_stocks('000300.XSHG')

# %%
price_df2 = price_df[price_df.symbol.isin(HF300_stocks)]

# %%
null_dict = check_for_nulls(price_df2.pivot(index='date',columns='symbol',values='close'))
# Out:
# 148 Nans in col 000001.XSHE
# 200 Nans in col 000002.XSHE
# 77 Nans in col 000060.XSHE
# 96 Nans in col 000063.XSHE
# 123 Nans in col 000069.XSHE
# 349 Nans in col 000100.XSHE
# 127 Nans in col 000157.XSHE
# 2472 Nans in col 000166.XSHE
# 2136 Nans in col 000333.XSHE
# 622 Nans in col 000338.XSHE
# 56 Nans in col 000402.XSHE
# 247 Nans in col 000413.XSHE
# 599 Nans in col 000415.XSHE
# 152 Nans in col 000423.XSHE
# 116 Nans in col 000425.XSHE
# 278 Nans in col 000503.XSHE
# 168 Nans in col 000538.XSHE
# 291 Nans in col 000540.XSHE
# 54 Nans in col 000559.XSHE
# 105 Nans in col 000568.XSHE
# 124 Nans in col 000623.XSHE
# 226 Nans in col 000625.XSHE
# 170 Nans in col 000627.XSHE
# 214 Nans in col 000630.XSHE
# 197 Nans in col 000651.XSHE
# 284 Nans in col 000671.XSHE
# 204 Nans in col 000709.XSHE
# 475 Nans in col 000723.XSHE
# 109 Nans in col 000725.XSHE
# 302 Nans in col 000728.XSHE
# 159 Nans in col 000768.XSHE
# 921 Nans in col 000776.XSHE
# 295 Nans in col 000783.XSHE
# 192 Nans in col 000786.XSHE
# 271 Nans in col 000792.XSHE
# 121 Nans in col 000826.XSHE
# 176 Nans in col 000839.XSHE
# 125 Nans in col 000858.XSHE
# 233 Nans in col 000876.XSHE
# 532 Nans in col 000895.XSHE
# 56 Nans in col 000898.XSHE
# 233 Nans in col 000938.XSHE
# 410 Nans in col 000959.XSHE
# 279 Nans in col 000961.XSHE
# 154 Nans in col 000963.XSHE
# 41 Nans in col 000983.XSHE
# 3154 Nans in col 001965.XSHE
# 2669 Nans in col 001979.XSHE
# 73 Nans in col 002007.XSHE
# 85 Nans in col 002008.XSHE
# 65 Nans in col 002024.XSHE
# 146 Nans in col 002027.XSHE
# 449 Nans in col 002044.XSHE
# 326 Nans in col 002050.XSHE
# 757 Nans in col 002065.XSHE
# 656 Nans in col 002074.XSHE
# 527 Nans in col 002081.XSHE
# 580 Nans in col 002085.XSHE
# 630 Nans in col 002142.XSHE
# 2543 Nans in col 601211.XSHG
# 2979 Nans in col 601212.XSHG
# 1544 Nans in col 601216.XSHG
# 2200 Nans in col 601225.XSHG
# 2971 Nans in col 601228.XSHG
# 2882 Nans in col 601229.XSHG
# 1769 Nans in col 601238.XSHG
# 1347 Nans in col 601288.XSHG
# 585 Nans in col 601318.XSHG
# 583 Nans in col 601328.XSHG
# 487 Nans in col 601333.XSHG
# 1717 Nans in col 601336.XSHG
# 1823 Nans in col 601360.XSHG
# 1420 Nans in col 601377.XSHG
# 727 Nans in col 601390.XSHG
# 459 Nans in col 601398.XSHG
# 1694 Nans in col 601555.XSHG
# 670 Nans in col 601600.XSHG
# 729 Nans in col 601601.XSHG
# 1267 Nans in col 601607.XSHG
# 2775 Nans in col 601611.XSHG
# 1226 Nans in col 601618.XSHG
# 496 Nans in col 601628.XSHG
# 1663 Nans in col 601633.XSHG
# 1116 Nans in col 601668.XSHG
# 1763 Nans in col 601669.XSHG
# 1260 Nans in col 601688.XSHG
# 1378 Nans in col 601718.XSHG
# 1189 Nans in col 601727.XSHG
# 978 Nans in col 601766.XSHG
# 1145 Nans in col 601788.XSHG
# 1744 Nans in col 601800.XSHG
# 675 Nans in col 601808.XSHG
# 1386 Nans in col 601818.XSHG
# 694 Nans in col 601857.XSHG
# 820 Nans in col 601866.XSHG
# 1369 Nans in col 601877.XSHG
# 3029 Nans in col 601878.XSHG
# 2929 Nans in col 601881.XSHG
# 1225 Nans in col 601888.XSHG
# 758 Nans in col 601898.XSHG
# 841 Nans in col 601899.XSHG
# 1723 Nans in col 601901.XSHG
# 784 Nans in col 601919.XSHG
# 1467 Nans in col 601933.XSHG
# 676 Nans in col 601939.XSHG
# 804 Nans in col 601958.XSHG
# 2532 Nans in col 601985.XSHG
# 376 Nans in col 601988.XSHG
# 1494 Nans in col 601989.XSHG
# 515 Nans in col 601991.XSHG
# 1521 Nans in col 601992.XSHG
# 2823 Nans in col 601997.XSHG
# 581 Nans in col 601998.XSHG
# 2860 Nans in col 603160.XSHG
# 3114 Nans in col 603260.XSHG
# 2205 Nans in col 603288.XSHG
# 2467 Nans in col 603799.XSHG
# 2976 Nans in col 603833.XSHG
# 2884 Nans in col 603858.XSHG
# 1906 Nans in col 603993.XSHG
# New shape of df:  (3159, 297)

# %%
stock_tickers = [symbol for symbol,nulls in null_dict.items() if nulls < 200]

# %%
asset_prices = price_df[price_df.symbol.isin(stock_tickers)].pivot(index='date',columns='symbol',values='close')

# %%
asset_prices['000300.XSHG'] = index_df['000300.XSHG']

# %%
asset_prices.head()
# Out:
# symbol      000001.XSHE  000060.XSHE  000063.XSHE  000069.XSHE  000157.XSHE  \
# date
# 2006-01-04         1.46         0.92         6.85          NaN         0.38
# 2006-01-05         1.47         0.94         6.85          NaN         0.39
# 2006-01-06         1.49         0.96         6.76         2.00         0.39
# 2006-01-09         1.48         0.99         6.79         1.92         0.40
# 2006-01-10         1.46         0.99         6.78         1.88         0.39
#
# symbol      000402.XSHE  000423.XSHE  000425.XSHE  000538.XSHE  000559.XSHE  \
# date
# 2006-01-04         2.08         3.37         0.40         4.67         0.82
# 2006-01-05         2.25         3.41         0.41         4.71         0.83
# 2006-01-06         2.26         3.52         0.40         4.88         0.84
# 2006-01-09         2.25         3.61         0.40         4.86         0.85
# 2006-01-10         2.27         3.59         0.42         4.86         0.85
#
# symbol         ...       600741.XSHG  600795.XSHG  600804.XSHG  600809.XSHG  \
# date           ...
# 2006-01-04     ...              0.93         0.91         0.48         2.65
# 2006-01-05     ...              0.95         0.93         0.49         2.64
# 2006-01-06     ...              0.95         0.93         0.50         2.68
# 2006-01-09     ...              0.94         0.93         0.50         2.69
# 2006-01-10     ...              0.94         0.90         0.50         2.65
#
# symbol      600820.XSHG  600837.XSHG  600867.XSHG  600886.XSHG  600887.XSHG  \
# date
# 2006-01-04          NaN         1.94         0.41         1.51         1.21
# 2006-01-05          NaN         2.00         0.42         1.53         1.21
# 2006-01-06          NaN         1.96         0.42         1.55         1.21
# 2006-01-09          NaN         1.97         0.42         1.55         1.28
# 2006-01-10          NaN         1.99         0.42         1.54         1.26
#
# symbol      000300.XSHG
# date
# 2006-01-04      941.428
# 2006-01-05      959.134
# 2006-01-06      970.032
# 2006-01-09      975.253
# 2006-01-10      978.154
#
# [5 rows x 102 columns]

# %% [markdown]
# \begin{align*}
# R_{ik} &= \frac{S_{i(t_0-(k-1)\Delta t)}-S_{i(t_0-k \Delta t)}}{S_{i(t_0-k \Delta t)}}\\
# Y_{ik} &= \frac{R_{ik}-\bar{R_i}}{\bar{\sigma_i}}\\
# \bar{R_i} &= \frac{1}{M} \sum_{k=1}^{M}R_{ik}\\
# \bar{\sigma_i}^2 &= \frac{1}{M-1} \sum_{k=1}^{M}(R_{ik}-\bar{R_i})^2
# \end{align*}

# %%
asset_returns = asset_prices.pct_change().dropna()
normed_returns = (asset_returns-asset_returns.mean())/asset_returns.std()

# %%
split_date = datetime.datetime(2016, 1, 1) 

df_train = normed_returns[normed_returns.index <= split_date].copy()
df_test = normed_returns[normed_returns.index > split_date].copy()

df_raw_train = asset_returns[asset_returns.index <= split_date].copy()
df_raw_test = asset_returns[asset_returns.index > split_date].copy()

print('Train dataset:', df_train.shape)
print('Test dataset:', df_test.shape)
# Out:
# Train dataset: (2419, 102)
# Test dataset: (488, 102)

# %%
n_tickers = len(stock_tickers)
pca = None
cov_matrix = pd.DataFrame(data=np.ones(shape=(n_tickers, n_tickers)), columns=stock_tickers)
cov_matrix_raw = cov_matrix

if df_train is not None and df_raw_train is not None:
    stock_tickers = asset_returns.columns.values[:-1]
    #assert 'SPX' not in stock_tickers, "By accident included SPX index"

    cov_matrix = df_train[stock_tickers].cov()
    cov_matrix_raw = df_raw_train[stock_tickers].cov()
    pca = sklearn.decomposition.PCA()
    pca.fit(cov_matrix)
    ### END CODE HERE ###
    
    if pca is not None:
        cov_raw_df = pd.DataFrame({'Variance': np.diag(cov_matrix_raw)}, index=stock_tickers)    
        # cumulative variance explained
        var_threshold = 0.8
        var_explained = np.cumsum(pca.explained_variance_ratio_)
        num_comp = np.where(np.logical_not(var_explained < var_threshold))[0][0] + 1  # +1 due to zero based-arrays
        print('%d components explain %.2f%% of variance' %(num_comp, 100* var_threshold))
# Out:
# 20 components explain 80.00% of variance

# %%
if pca is not None:
    bar_width = 0.9
    n_asset = int((1 / 10) * normed_returns.shape[1])
    x_indx = np.arange(n_asset)
    fig, ax = plt.subplots()
    fig.set_size_inches(12, 4)
    # Eigenvalues are measured as percentage of explained variance.
    rects = ax.bar(x_indx, pca.explained_variance_ratio_[:n_asset], bar_width, color='deepskyblue')
    ax.set_xticks(x_indx + bar_width / 2)
    ax.set_xticklabels(list(range(n_asset)), rotation=45)
    ax.set_title('Percent variance explained')
    ax.legend((rects[0],), ('Percent variance explained by principal components',))

# %%
if pca is not None:
    projected = pca.fit_transform(cov_matrix)

# %%
# the first two eigen-portfolio weights
# first component
# get the Principal components
pc_w = np.zeros(len(stock_tickers))
eigen_prtf1 = pd.DataFrame(data ={'weights': pc_w.squeeze()*100}, index = stock_tickers)
if pca is not None:
    pcs = pca.components_

    pc_w = pcs[:,0]/pcs[:,0].sum()

    eigen_prtf1 = pd.DataFrame(data ={'weights': pc_w.squeeze()*100}, index = stock_tickers)
    eigen_prtf1.sort_values(by=['weights'], ascending=False, inplace=True)
    print('Sum of weights of first eigen-portfolio: %.2f' % np.sum(eigen_prtf1))
    eigen_prtf1.plot(title='First eigen-portfolio weights', 
                     figsize=(12,6), 
                     xticks=range(0, len(stock_tickers),10), 
                     rot=45, 
                     linewidth=3)
# Out:
# Sum of weights of first eigen-portfolio: 100.00

# %%
pc_w = np.zeros(len(stock_tickers))
eigen_prtf2 = pd.DataFrame(data ={'weights': pc_w.squeeze()*100}, index = stock_tickers)

if pca is not None:
    pcs = pca.components_
    
    ### START CODE HERE ### (≈ 1-2 lines of code)
    pc_w = pcs[:,1]/pcs[:,1].sum()
    
    ### END CODE HERE ###

    eigen_prtf2 = pd.DataFrame(data ={'weights': pc_w.squeeze()*100}, index = stock_tickers)
    eigen_prtf2.sort_values(by=['weights'], ascending=False, inplace=True)
    print('Sum of weights of second eigen-portfolio: %.2f' % np.sum(eigen_prtf2))
    eigen_prtf2.plot(title='Second eigen-portfolio weights',
                     figsize=(12,6), 
                     xticks=range(0, len(stock_tickers),10), 
                     rot=45, 
                     linewidth=3)
# Out:
# Sum of weights of second eigen-portfolio: 100.00

# %%
def sharpe_ratio(ts_returns, periods_per_year=252):
    """
    sharpe_ratio - Calculates annualized return, annualized vol, and annualized sharpe ratio, 
                    where sharpe ratio is defined as annualized return divided by annualized volatility 
                    
    Arguments:
    ts_returns - pd.Series of returns of a single eigen portfolio
    
    Return:
    a tuple of three doubles: annualized return, volatility, and sharpe ratio
    """
    annualized_return = ts_returns.mean()*periods_per_year
    annualized_vol  = ts_returns.std()*np.sqrt(periods_per_year)
    annualized_sharpe = annualized_return/annualized_vol
    
    return annualized_return, annualized_vol, annualized_sharpe

# %%
if df_raw_test is not None:
    eigen_prtf1_returns = np.dot(df_raw_test.loc[:, eigen_prtf1.index], eigen_prtf1 / 100)
    eigen_prtf1_returns = pd.Series(eigen_prtf1_returns.squeeze(), index=df_test.index)
    er, vol, sharpe = sharpe_ratio(eigen_prtf1_returns)
    print('First eigen-portfolio:\nReturn = %.2f%%\nVolatility = %.2f%%\nSharpe = %.2f' % (er*100, vol*100, sharpe))
    year_frac = (eigen_prtf1_returns.index[-1] - eigen_prtf1_returns.index[0]).days / 252

    df_plot = pd.DataFrame({'PC1': eigen_prtf1_returns, '000300.XSHG': df_raw_test.loc[:, '000300.XSHG']}, index=df_test.index)
    np.cumprod(df_plot + 1).plot(title='Returns of the market-cap weighted index vs. First eigen-portfolio', 
                             figsize=(12,6), linewidth=3)
# Out:
# First eigen-portfolio:
# Return = 33.30%
# Volatility = 38.37%
# Sharpe = 0.87

# %%
if df_raw_test is not None:
    eigen_prtf2_returns = np.dot(df_raw_test.loc[:, eigen_prtf2.index], eigen_prtf2 / 100)
    eigen_prtf2_returns = pd.Series(eigen_prtf2_returns.squeeze(), index=df_test.index)
    er, vol, sharpe = sharpe_ratio(eigen_prtf2_returns)
    print('Second eigen-portfolio:\nReturn = %.2f%%\nVolatility = %.2f%%\nSharpe = %.2f' % (er*100, vol*100, sharpe))
# Out:
# Second eigen-portfolio:
# Return = 5.76%
# Volatility = 26.30%
# Sharpe = 0.22

# %%
n_portfolios = 120
annualized_ret = np.array([0.] * n_portfolios)
sharpe_metric = np.array([0.] * n_portfolios)
annualized_vol = np.array([0.] * n_portfolios)
idx_highest_sharpe = 0 # index into sharpe_metric which identifies a portfolio with rhe highest Sharpe ratio
    
if pca is not None:
    for ix in range(n_portfolios):
        
        ### START CODE HERE ### (≈ 4-5 lines of code)
        #eigen_prtf1 = pd.DataFrame(data ={'weights': pc_w.squeeze()*100}, index = stock_tickers)
        #eigen_prtf1.sort_values(by=['weights'], ascending=False, inplace=True)
        eigen_prtf_returns = np.dot(df_raw_test.loc[:, eigen_prtf1.index[:(ix+1)]], eigen_prtf1[:(ix+1)] / 100)
        eigen_prtf_returns = pd.Series(eigen_prtf_returns.squeeze(), index=df_test.index)
        er, vol, sharpe = sharpe_ratio(eigen_prtf_returns)
        annualized_ret[ix] = er
        annualized_vol[ix] = vol
        sharpe_metric[ix] = er/vol
        ### END CODE HERE ###
    
    
    # find portfolio with the highest Sharpe ratio
    ### START CODE HERE ### (≈ 2-3 lines of code)
    ### ...
    idx_highest_sharpe = np.argmax(sharpe_metric)
    ### END CODE HERE ###
    
    print('Eigen portfolio #%d with the highest Sharpe. Return %.2f%%, vol = %.2f%%, Sharpe = %.2f' % 
          (idx_highest_sharpe,
           annualized_ret[idx_highest_sharpe]*100, 
           annualized_vol[idx_highest_sharpe]*100, 
           sharpe_metric[idx_highest_sharpe]))

    fig, ax = plt.subplots()
    fig.set_size_inches(12, 4)
    ax.plot(sharpe_metric, linewidth=3)
    ax.set_title('Sharpe ratio of eigen-portfolios')
    ax.set_ylabel('Sharpe ratio')
    ax.set_xlabel('Portfolios')
# Out:
# Eigen portfolio #0 with the highest Sharpe. Return 19.94%, vol = 12.76%, Sharpe = 1.56

# %%
results = pd.DataFrame(data={'Return': annualized_ret, 'Vol': annualized_vol, 'Sharpe': sharpe_metric})
results.sort_values(by=['Sharpe'], ascending=False, inplace=True)
results.head(10)
# Out:
#       Return       Vol    Sharpe
# 0   0.199380  0.127649  1.561943
# 2   0.304200  0.288161  1.055659
# 85  0.691229  0.715093  0.966627
# 82  0.730722  0.767226  0.952421
# 87  0.632873  0.668934  0.946092
# 84  0.690297  0.734814  0.939417
# 81  0.723154  0.781815  0.924967
# 83  0.699838  0.759313  0.921672
# 79  0.743907  0.816518  0.911073
# 88  0.586349  0.649972  0.902115

# %%
2*24*30
# Out:
# 1440
